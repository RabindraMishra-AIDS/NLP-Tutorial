# %% [markdown]
# ## Gensim,Word2Vec

# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors

# %%
# !pip install wget

# %%
import gensim.downloader as api
model = api.load('word2vec-google-news-300') #Loading Google pre trained dataset

# %%
model['man'].shape
# Out:
# (300,)

# %% [markdown]
# #### Most Numbers would be Non zero

# %%
model['man'] #Vector representation of word 'man' as a 300 dimension
# Out:
# array([ 0.32617188,  0.13085938,  0.03466797, -0.08300781,  0.08984375,
#        -0.04125977, -0.19824219,  0.00689697,  0.14355469,  0.0019455 ,
#         0.02880859, -0.25      , -0.08398438, -0.15136719, -0.10205078,
#         0.04077148, -0.09765625,  0.05932617,  0.02978516, -0.10058594,
#        -0.13085938,  0.001297  ,  0.02612305, -0.27148438,  0.06396484,
#        -0.19140625, -0.078125  ,  0.25976562,  0.375     , -0.04541016,
#         0.16210938,  0.13671875, -0.06396484, -0.02062988, -0.09667969,
#         0.25390625,  0.24804688, -0.12695312,  0.07177734,  0.3203125 ,
#         0.03149414, -0.03857422,  0.21191406, -0.00811768,  0.22265625,
#        -0.13476562, -0.07617188,  0.01049805, -0.05175781,  0.03808594,
#        -0.13378906,  0.125     ,  0.0559082 , -0.18261719,  0.08154297,
#        -0.08447266, -0.07763672, -0.04345703,  0.08105469, -0.01092529,
#         0.17480469,  0.30664062, -0.04321289, -0.01416016,  0.09082031,
# ...

# %%
model['Rabindra']
# Out:
# array([-0.1796875 ,  0.36914062,  0.22167969,  0.171875  , -0.09765625,
#        -0.10693359,  0.17285156, -0.09082031, -0.2421875 , -0.06787109,
#        -0.03710938, -0.19042969, -0.02246094,  0.04345703, -0.16308594,
#         0.07421875, -0.34375   , -0.18066406,  0.26367188, -0.13378906,
#         0.13769531, -0.36132812,  0.02270508,  0.21386719, -0.08056641,
#        -0.03881836, -0.18261719, -0.34375   ,  0.03417969, -0.21679688,
#        -0.33007812, -0.40429688,  0.09912109,  0.12695312,  0.17871094,
#        -0.10888672,  0.00137329, -0.21972656,  0.24902344, -0.24414062,
#        -0.15136719,  0.14746094,  0.19921875,  0.5234375 , -0.16113281,
#        -0.33007812, -0.09179688,  0.10644531,  0.22851562, -0.07714844,
#        -0.21582031,  0.07275391,  0.22949219, -0.10449219, -0.05493164,
#        -0.06982422, -0.14941406, -0.1484375 ,  0.375     , -0.375     ,
#         0.15722656, -0.08642578,  0.22558594, -0.3671875 ,  0.2109375 ,
# ...

# %%
model['Mishra'] #Vector representation of word Mishra
# Out:
# array([ 1.38671875e-01,  3.98437500e-01,  2.59765625e-01,  2.18750000e-01,
#        -1.42578125e-01, -2.45117188e-01, -7.27539062e-02, -9.76562500e-02,
#        -1.32812500e-01, -8.39843750e-02, -1.29882812e-01,  1.48925781e-02,
#         5.34667969e-02, -1.02050781e-01, -2.77343750e-01,  2.23632812e-01,
#        -1.01562500e-01, -3.26171875e-01,  1.10839844e-01,  9.42382812e-02,
#         1.16699219e-01, -2.63671875e-01,  2.00195312e-02, -2.96630859e-02,
#        -4.22363281e-02,  3.96728516e-03, -4.53125000e-01, -2.59765625e-01,
#        -4.91333008e-03, -1.30859375e-01, -3.51562500e-01, -3.00781250e-01,
#        -7.37304688e-02,  1.46484375e-01, -3.08837891e-02,  4.32128906e-02,
#        -7.32421875e-02, -2.45117188e-01,  2.73437500e-01, -2.73437500e-01,
#         1.88476562e-01,  1.70898438e-01,  1.49414062e-01,  3.90625000e-01,
#        -4.68750000e-02, -3.39843750e-01, -6.37817383e-03, -5.24902344e-02,
# ...

# %%
model.most_similar('Rabindra')
# Out:
# [('Surendra', 0.6877127885818481),
#  ('Sukanta', 0.6849691867828369),
#  ('Prafulla', 0.6769298315048218),
#  ('Pradhan', 0.675473690032959),
#  ('Sumanta', 0.674187421798706),
#  ('Basudev', 0.6717303395271301),
#  ('Adhikari', 0.6708546876907349),
#  ('Shashidhar', 0.6696672439575195),
#  ('Chandra_Das', 0.6650339365005493),
#  ('Gautam', 0.6631878614425659)]

# %%
model.most_similar('Utkarsh')
# Out:
# [('Bhavya', 0.7528684735298157),
#  ('Sanchit', 0.7117987275123596),
#  ('Manoj', 0.7089168429374695),
#  ('Mayank', 0.7087859511375427),
#  ('Vipin', 0.7086341977119446),
#  ('Aniruddh', 0.705639660358429),
#  ('Pratyush', 0.705297589302063),
#  ('Rishab', 0.70447838306427),
#  ('Harshal', 0.7035053372383118),
#  ('Sanket', 0.7034469842910767)]

# %%
model.most_similar('India')
# Out:
# [('Indias', 0.7384199500083923),
#  ('Indiaâ_€_™', 0.6843485832214355),
#  ('Pakistan', 0.6706860661506653),
#  ('Delhi', 0.6632035374641418),
#  ('Bangalore', 0.6583030819892883),
#  ('subcontinent', 0.6579218506813049),
#  ('Bangladesh', 0.6527796983718872),
#  ('sub_continent', 0.6503037810325623),
#  ('Mumbai', 0.6495688557624817),
#  ('Sri_Lanka', 0.6445952653884888)]

# %% [markdown]
# #### doesnt_match Function

# %%
model.doesnt_match(['Cricket','NASA','ISRO'])
# Out:
# 'Cricket'

# %% [markdown]
# ## Vector Operation

# %%
vec1=model['wicket']+model['run']-model['ball']
model.most_similar([vec1])
# Out:
# [('wicket', 0.7673004269599915),
#  ('wickets', 0.6575860977172852),
#  ('five_wicket_haul', 0.6248893141746521),
#  ('wicket_haul', 0.6152182221412659),
#  ('overs', 0.5865299105644226),
#  ('skittled', 0.5617733597755432),
#  ('Di_Venuto', 0.5555180907249451),
#  ('nightwatchman', 0.5500483512878418),
#  ('Gareth_Breese', 0.5395625829696655),
#  ('medium_pacer', 0.5360080599784851)]

# %%
vec2=model['Math']+model['Chemistry']+model['Physics']+model['Cutoff']
model.most_similar([vec2])
# Out:
# [('Physics', 0.7934616804122925),
#  ('Chemistry', 0.751605749130249),
#  ('Math', 0.7307701110839844),
#  ('Mathematics', 0.6791397333145142),
#  ('Biology', 0.6126805543899536),
#  ('Linear_Algebra', 0.6003521680831909),
#  ('Science', 0.5937017798423767),
#  ('Biology_Physics', 0.5856563448905945),
#  ('Intermediate_Algebra', 0.5669636130332947),
#  ('Computer_Science', 0.565693199634552)]
